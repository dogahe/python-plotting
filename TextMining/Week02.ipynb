# %%
import nltk

# %%
#nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
sents()
# Out:
# sent1: Call me Ishmael .
# sent2: The family of Dashwood had long been settled in Sussex .
# sent3: In the beginning God created the heaven and the earth .
# sent4: Fellow - Citizens of the Senate and of the House of Representatives :
# sent5: I have a problem with people PMing me to lol JOIN
# sent6: SCENE 1 : [ wind ] [ clop clop clop ] KING ARTHUR : Whoa there !
# sent7: Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# sent8: 25 SEXY MALE , seeks attrac older single lady , for discreet encounters .
# sent9: THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
len(text7)
# Out:
# 100676

# %%
len(set(text7))
# Out:
# 12408

# %%
list(set(text7))[:10]
# Out:
# ['buckle',
#  'reason',
#  'possibly',
#  'real',
#  'Among',
#  'guest',
#  'harvested',
#  'Hammerton',
#  'syndicate',
#  '3.04']

# %%
dist = FreqDist(text7)

# %%
len(dist)
# Out:
# 12408

# %%
vocab1 = dist.keys()

# %%
list(vocab1)[:10]
# Out:
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', 'will', 'join', 'the', 'board']

# %%
dist['four']
# Out:
# 20

# %%
freqwords = [w for w in vocab1 if len(w) > 5 and dist[w] > 100]

# %%
freqwords
# Out:
# ['billion',
#  'company',
#  'president',
#  'because',
#  'market',
#  'million',
#  'shares',
#  'trading',
#  'program']

# %%
input1 = "List listed lists listing listings"
words1 = input1.lower().split(' ')
words1
# Out:
# ['list', 'listed', 'lists', 'listing', 'listings']

# %%
porter = nltk.PorterStemmer()
[porter.stem(t) for t in words1]
# Out:
# ['list', 'list', 'list', 'list', 'list']

# %%
porter.stem("catches")
# Out:
# 'catch'

# %%
udhr = nltk.corpus.udhr.words('English-Latin1')

# %%
udhr[:20]
# Out:
# ['Universal',
#  'Declaration',
#  'of',
#  'Human',
#  'Rights',
#  'Preamble',
#  'Whereas',
#  'recognition',
#  'of',
#  'the',
#  'inherent',
#  'dignity',
#  'and',
#  'of',
#  'the',
#  'equal',
#  'and',
#  'inalienable',
#  'rights',
#  'of']

# %%
[porter.stem(t) for t in udhr[:20]]
# Out:
# ['univers',
#  'declar',
#  'of',
#  'human',
#  'right',
#  'preambl',
#  'wherea',
#  'recognit',
#  'of',
#  'the',
#  'inher',
#  'digniti',
#  'and',
#  'of',
#  'the',
#  'equal',
#  'and',
#  'inalien',
#  'right',
#  'of']

# %%
WNlemma = nltk.WordNetLemmatizer()

# %%
[WNlemma.lemmatize(t) for t in udhr[:20]]
# Out:
# ['Universal',
#  'Declaration',
#  'of',
#  'Human',
#  'Rights',
#  'Preamble',
#  'Whereas',
#  'recognition',
#  'of',
#  'the',
#  'inherent',
#  'dignity',
#  'and',
#  'of',
#  'the',
#  'equal',
#  'and',
#  'inalienable',
#  'right',
#  'of']

# %%
text11 = "Children shouldn't drink a sugary drink before bed."
text11.split(' ')
# Out:
# ['Children', "shouldn't", 'drink', 'a', 'sugary', 'drink', 'before', 'bed.']

# %%
nltk.word_tokenize(text11)
# Out:
# ['Children',
#  'should',
#  "n't",
#  'drink',
#  'a',
#  'sugary',
#  'drink',
#  'before',
#  'bed',
#  '.']

# %%
text12 = "This is the first sentence. A gallon of milk in the U.S. costs $2.99. Is this the third sentence? Yes, it is!"
sentences = nltk.sent_tokenize(text12)
len(sentences)
# Out:
# 4

# %%
sentences
# Out:
# ['This is the first sentence.',
#  'A gallon of milk in the U.S. costs $2.99.',
#  'Is this the third sentence?',
#  'Yes, it is!']

# %%
nltk.help.upenn_tagset('MD')
# Out:
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would

# %%
text13 = nltk.word_tokenize(text11)

# %%
nltk.pos_tag(text13)
# Out:
# [('Children', 'NNP'),
#  ('should', 'MD'),
#  ("n't", 'RB'),
#  ('drink', 'VB'),
#  ('a', 'DT'),
#  ('sugary', 'JJ'),
#  ('drink', 'NN'),
#  ('before', 'IN'),
#  ('bed', 'NN'),
#  ('.', '.')]

# %%
text14 = nltk.word_tokenize("Visiting aunts can be a nuisance")
nltk.pos_tag(text14)
# Out:
# [('Visiting', 'VBG'),
#  ('aunts', 'NNS'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('a', 'DT'),
#  ('nuisance', 'NN')]

# %%
# Parsing sentence structure
text15 = nltk.word_tokenize("Alice loves Bob")

# %%
grammar = nltk.CFG.fromstring("""
S -> NP VP
VP -> V NP
NP -> 'Alice' | 'Bob'
V -> 'loves'
""")

# %%
parser = nltk.ChartParser(grammar)
trees = parser.parse_all(text15)

# %%
for tree in trees:
    print(tree)
# Out:
# (S (NP Alice) (VP (V loves) (NP Bob)))

# %%
text16 = nltk.word_tokenize("I saw the man with a telescope")
grammar1 = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'a' | 'the'
N -> 'man' | 'telescope'
V -> 'saw'
P -> 'with'
""")

# %%
parser = nltk.ChartParser(grammar1)
trees = parser.parse_all(text16)
for tree in trees:
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V saw) (NP (Det the) (N man)))
#     (PP (P with) (NP (Det a) (N telescope)))))
# (S
#   (NP I)
#   (VP
#     (V saw)
#     (NP (Det the) (N man) (PP (P with) (NP (Det a) (N telescope))))))

# %%
from nltk.corpus import treebank
text17 = treebank.parsed_sents('wsj_0001.mrg')[0]
print(text17)
# Out:
# (S
#   (NP-SBJ
#     (NP (NNP Pierre) (NNP Vinken))
#     (, ,)
#     (ADJP (NP (CD 61) (NNS years)) (JJ old))
#     (, ,))
#   (VP
#     (MD will)
#     (VP
#       (VB join)
#       (NP (DT the) (NN board))
#       (PP-CLR (IN as) (NP (DT a) (JJ nonexecutive) (NN director)))
#       (NP-TMP (NNP Nov.) (CD 29))))
#   (. .))

# %%
text18 = nltk.word_tokenize("The old man the boat")
nltk.pos_tag(text18)
# Out:
# [('The', 'DT'), ('old', 'JJ'), ('man', 'NN'), ('the', 'DT'), ('boat', 'NN')]

# %%
text19 = nltk.word_tokenize("Colorless green ideas sleep furiously")
nltk.pos_tag(text19)
# Out:
# [('Colorless', 'NNP'),
#  ('green', 'JJ'),
#  ('ideas', 'NNS'),
#  ('sleep', 'VBP'),
#  ('furiously', 'RB')]

# %%
'jJjs'.islower()
# Out:
# False

# %%
'jJjs'.upper()
# Out:
# 'JJJS'

# %%
'   jJjs  '.rstrip()
# Out:
# '   jJjs'

# %%
text19
# Out:
# ['Colorless', 'green', 'ideas', 'sleep', 'furiously']

# %% [markdown]
# # Assignment 2

# %% [markdown]
# ## Part 1 - Analyzing Moby Dick

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
total_tokens = len(text1)
total_tokens
# Out:
# 260819

# %%
unique_tokens = len(set(text1))

# %%
lemmatizer = nltk.WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(w,'v') for w in text1]
len(set(lemmatized))
# Out:
# 15363

# %%
unique_tokens/total_tokens
# Out:
# 0.07406285585022564

# %%
whales = [(w == "Whale" or w == "whale") for w in text1].count(True)
whales
# Out:
# 1188

# %%
whales/total_tokens
# Out:
# 0.00455488288813315

# %%
wordlist = set(text1)
wordfreq = []
for w in wordlist:
    wordfreq.append(text1.count(w))

# %%
wordCount = list(zip(wordlist, wordfreq))

# %%
wordCountSorted = sorted(wordCount, key=lambda x: x[1])

# %%
wordCountSorted[-20:]
# Out:
# [('was', 1632),
#  ('with', 1659),
#  ('he', 1661),
#  ('is', 1695),
#  ('s', 1739),
#  ('I', 2124),
#  ('it', 2209),
#  ('his', 2459),
#  ('-', 2552),
#  ("'", 2684),
#  ('that', 2982),
#  ('in', 3916),
#  (';', 4072),
#  ('to', 4542),
#  ('a', 4569),
#  ('and', 6024),
#  ('of', 6536),
#  ('.', 6862),
#  ('the', 13721),
#  (',', 18713)]

# %%
wordCountSortedFiltered = [w for w in wordCountSorted if (len(w[0]) > 5 and w[1] > 150)]

# %%
wordCountSortedFilteredSorted = sorted(wordCountSortedFiltered, key=lambda x: x[0])

# %%
wordCountSortedFilteredSorted
# Out:
# [('Captain', 215),
#  ('Pequod', 172),
#  ('Queequeg', 252),
#  ('Starbuck', 196),
#  ('almost', 186),
#  ('before', 293),
#  ('himself', 203),
#  ('little', 247),
#  ('seemed', 283),
#  ('should', 181),
#  ('though', 335),
#  ('through', 227),
#  ('whales', 237),
#  ('without', 154)]

# %%
wordLengths = [(w, len(w)) for w in text1]
wordLengths
# Out:
# [('[', 1),
#  ('Moby', 4),
#  ('Dick', 4),
#  ('by', 2),
#  ('Herman', 6),
#  ('Melville', 8),
#  ('1851', 4),
#  (']', 1),
#  ('ETYMOLOGY', 9),
#  ('.', 1),
#  ('(', 1),
#  ('Supplied', 8),
#  ('by', 2),
#  ('a', 1),
#  ('Late', 4),
#  ('Consumptive', 11),
#  ('Usher', 5),
#  ('to', 2),
#  ('a', 1),
#  ('Grammar', 7),
#  ('School', 6),
#  (')', 1),
#  ('The', 3),
#  ('pale', 4),
#  ('Usher', 5),
#  ('--', 2),
#  ('threadbare', 10),
#  ('in', 2),
#  ('coat', 4),
#  (',', 1),
#  ('heart', 5),
#  (',', 1),
#  ('body', 4),
#  (',', 1),
#  ('and', 3),
#  ('brain', 5),
#  (';', 1),
#  ('I', 1),
#  ('see', 3),
#  ('him', 3),
#  ('now', 3),
#  ('.', 1),
#  ('He', 2),
#  ('was', 3),
#  ('ever', 4),
#  ('dusting', 7),
#  ('his', 3),
#  ('old', 3),
#  ('lexicons', 8),
#  ('and', 3),
#  ('grammars', 8),
#  (',', 1),
#  ('with', 4),
#  ('a', 1),
#  ('queer', 5),
#  ('handkerchief', 12),
#  (',', 1),
#  ('mockingly', 9),
#  ('embellished', 11),
#  ('with', 4),
#  ('all', 3),
#  ('the', 3),
# ...

# %%
wordLengthsSorted = sorted(wordLengths, key=lambda x: x[1], reverse = True)
wordLengthsSorted
# Out:
# [('uninterpenetratingly', 20),
#  ('characteristically', 18),
#  ('uncomfortableness', 17),
#  ('cannibalistically', 17),
#  ('circumnavigations', 17),
#  ('superstitiousness', 17),
#  ('superstitiousness', 17),
#  ('comprehensiveness', 17),
#  ('preternaturalness', 17),
#  ('indispensableness', 17),
#  ('comprehensiveness', 17),
#  ('comprehensiveness', 17),
#  ('uncompromisedness', 17),
#  ('subterraneousness', 17),
#  ('CIRCUMNAVIGATION', 16),
#  ('apprehensiveness', 16),
#  ('indiscriminately', 16),
#  ('indiscriminately', 16),
#  ('circumnavigating', 16),
#  ('circumnavigation', 16),
#  ('apprehensiveness', 16),
#  ('indiscriminately', 16),
#  ('simultaneousness', 16),
#  ('apprehensiveness', 16),
#  ('undiscriminating', 16),
#  ('irresistibleness', 16),
#  ('Physiognomically', 16),
#  ('physiognomically', 16),
#  ('physiognomically', 16),
#  ('circumnavigation', 16),
#  ('hermaphroditical', 16),
#  ('circumnavigating', 16),
#  ('responsibilities', 16),
# ...

# %%
wordCountSortedAlpha = [w for w in wordCountSorted if w[0].isalpha()]

# %%
wordCountSortedAlpha[-20:]
# Out:
# [('at', 1231),
#  ('this', 1280),
#  ('for', 1414),
#  ('all', 1462),
#  ('as', 1620),
#  ('was', 1632),
#  ('with', 1659),
#  ('he', 1661),
#  ('is', 1695),
#  ('s', 1739),
#  ('I', 2124),
#  ('it', 2209),
#  ('his', 2459),
#  ('that', 2982),
#  ('in', 3916),
#  ('to', 4542),
#  ('a', 4569),
#  ('and', 6024),
#  ('of', 6536),
#  ('the', 13721)]

# %%
with open('moby.txt', 'r') as f:
    moby_raw = f.read()

# %%
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(moby_raw)

# %%
sentence_tokens_count = [len(nltk.word_tokenize(sentence)) for sentence in sentences]

# %%
sum(sentence_tokens_count)/len(sentence_tokens_count)
# Out:
# 25.88489646772229

# %%
part_of_speech = nltk.pos_tag(moby_raw)

# %%
just_part_of_speech = [w[1] for w in part_of_speech]

# %%
just_part_of_speech
# Out:
# ['JJ',
#  'NNP',
#  'NN',
#  'NN',
#  'NN',
#  'NNP',
#  'NNP',
#  'NN',
#  'VBP',
#  'NN',
#  'NNP',
#  'NN',
#  'NN',
#  'NNP',
#  'NNP',
#  'NN',
#  'NN',
#  'VBD',
#  'DT',
#  'JJ',
#  'NNP',
#  'NNP',
#  'NN',
#  'NN',
#  'NN',
#  'NN',
#  'VBP',
#  'NN',
#  'NN',
#  'VBD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'NN',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  '.',
#  'NN',
#  'NN',
#  '(',
#  'NNP',
#  'RB',
#  'VBZ',
#  'JJ',
#  'NN',
#  'NN',
#  'VBP',
#  'NN',
#  'NN',
#  'NN',
#  'NN',
#  'VBZ',
#  'DT',
#  'JJ',
#  'NNP',
#  'DT',
#  'NN',
#  'NN',
#  'NNP',
#  'NNP',
#  'MD',
#  'VB',
#  'JJ',
#  'JJ',
#  'NN',
#  'NN',
#  'NN',
#  'NN',
#  'VBP',
#  'NN',
#  'NNP',
#  'NNP',
#  'VBD',
#  'PRP$',
#  'JJ',
#  'NN',
#  'NNP',
#  'NN',
#  'NN',
#  'VBZ',
#  'DT',
#  'NN',
#  'NNP',
#  'VBZ',
#  'DT',
#  'NN',
#  'NN',
#  'DT',
#  'NN',
#  'NNP',
#  'NNP',
#  'VBZ',
#  'JJ',
#  'JJ',
#  'NN',
# ...

# %%
poslist = set(just_part_of_speech)
posfreq = []
for w in just_part_of_speech:
    posfreq.append(just_part_of_speech.count(w))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-8f8c6e664396> in <module>
#       2 posfreq = []
#       3 for w in just_part_of_speech:
# ----> 4     posfreq.append(just_part_of_speech.count(w))
#
# KeyboardInterrupt:

# %%
posCount = list(zip(poslist, posfreq))

# %% [markdown]
# ## Part 2 - Spelling Recommender
#
# For this part of the assignment you will create three different spelling recommenders, that each take a list of misspelled words and recommends a correctly spelled word for every word in the list.
#
# For every misspelled word, the recommender should find find the word in `correct_spellings` that has the shortest distance*, and starts with the same letter as the misspelled word, and return that word as a recommendation.
#
# *Each of the three different recommenders will use a different distance measure (outlined below).
#
# Each of the recommenders should provide recommendations for the three default words provided: `['cormulent', 'incendenece', 'validrate']`.

# %%
from nltk.corpus import words
correct_spellings = words.words()

# %%
correct_spellings
# Out:
# ['A',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'Aani',
#  'aardvark',
#  'aardwolf',
#  'Aaron',
#  'Aaronic',
#  'Aaronical',
#  'Aaronite',
#  'Aaronitic',
#  'Aaru',
#  'Ab',
#  'aba',
#  'Ababdeh',
#  'Ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'Abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'Abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'Abanic',
#  'Abantes',
#  'abaptiston',
#  'Abarambo',
#  'Abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'Abasgi',
#  'abash',
#  'abashed',
# ...
